# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np

seq_len = 128

# %%
df = pd.read_csv('./s&p500_3years.csv', delimiter=',')

# %%
# Convert str to datetime in column "date"
df["date"] = pd.Series([datetime.strptime(x[:-6], "%Y-%m-%d %H:%M:%S") for x in df["date"]])

# %%
df
# Out:
#                      date  open  high  low  close  volume  is_ext
# 0     2018-04-02 13:00:00   190   190  188    189    9892   False
# 1     2018-04-02 14:00:00   188   188  186    186   34335   False
# 2     2018-04-02 15:00:00   186   186  184    185   35470    True
# 3     2018-04-02 16:00:00   185   187  184    185   25025   False
# 4     2018-04-02 17:00:00   185   186  184    184   23102    True
# ...                   ...   ...   ...  ...    ...     ...     ...
# 10946 2022-01-28 18:00:00   397   400  397    399   17133   False
# 10947 2022-01-28 19:00:00   400   401  396    401   24383   False
# 10948 2022-01-28 20:00:00   401   406  401    406   68026   False
# 10949 2022-01-28 21:00:00   406   409  400    407     404   False
# 10950 2022-01-28 22:00:00   409   409  409    409       1   False
#
# [10951 rows x 7 columns]

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['close'])
plt.xticks(range(0, df.shape[0], 24*30*2), [x.date() for x in df['date'].loc[::24*30*2]], rotation=0)
plt.ylabel('price', fontsize=18)
plt.title("Close Price - Moving Average", fontsize=20)
plt.legend(['Close Price'], fontsize='x-large', loc='best')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['volume'])
plt.xticks(range(0, df.shape[0], 24*30*2), df['date'].loc[::24*30*2], rotation=0)
plt.ylabel('Volume', fontsize=18)
plt.title("Volume - Moving Average", fontsize=20)
plt.legend(['Volume'], fontsize='x-large', loc='best')
plt.show()

# %%
'''Normalize price columns'''

df['open'] = (df['open']-np.mean(df['open']))/np.std(df['open'])
df['high'] = (df['high']-np.mean(df['high']))/np.std(df['high'])
df['low'] = (df['low']-np.mean(df['low']))/np.std(df['low']) 
df['close'] = (df['close']-np.mean(df['close']))/np.std(df['close'])
df['volume'] = (df['volume']-np.mean(df['volume']))/np.std(df['volume'])

df.head()
# Out:
#                  date      open      high       low     close    volume  \
# 0 2018-04-02 13:00:00 -1.507780 -1.515642 -1.522882 -1.519477 -0.342147
# 1 2018-04-02 14:00:00 -1.531133 -1.538941 -1.546295 -1.554513  0.777023
# 2 2018-04-02 15:00:00 -1.554485 -1.562241 -1.569708 -1.566192  0.828991
# 3 2018-04-02 16:00:00 -1.566162 -1.550591 -1.569708 -1.566192  0.350747
# 4 2018-04-02 17:00:00 -1.566162 -1.562241 -1.569708 -1.577870  0.262698
#
#    is_ext
# 0   False
# 1   False
# 2    True
# 3   False
# 4    True

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['close'])
plt.xticks(range(0, df.shape[0], 24*30*2), [x.date() for x in df['date'].loc[::24*30*2]], rotation=0)
plt.ylabel('price', fontsize=18)
plt.title("Close Price - Moving Average", fontsize=20)
plt.legend(['Close Price'], fontsize='x-large', loc='best')
plt.show()

# %%
times = df.index.values
last_10pct = df.index.values[-int(0.1*len(times))] # Last 10% of series
last_20pct = df.index.values[-int(0.2*len(times))] # Last 20% of series
print(df.head())
df.columns
# Out:
#                  date      open      high       low     close    volume  \
# 0 2018-04-02 13:00:00 -1.507780 -1.515642 -1.522882 -1.519477 -0.342147
# 1 2018-04-02 14:00:00 -1.531133 -1.538941 -1.546295 -1.554513  0.777023
# 2 2018-04-02 15:00:00 -1.554485 -1.562241 -1.569708 -1.566192  0.828991
# 3 2018-04-02 16:00:00 -1.566162 -1.550591 -1.569708 -1.566192  0.350747
# 4 2018-04-02 17:00:00 -1.566162 -1.562241 -1.569708 -1.577870  0.262698
#
#    is_ext
# 0   False
# 1   False
# 2    True
# 3   False
# 4    True
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'is_ext'], dtype='object')

# %%
###############################################################################
'''Create training, validation and test split'''

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# Remove date column
df_train.drop(columns=['date', 'is_ext'], inplace=True)
df_val.drop(columns=['date', 'is_ext'], inplace=True)
df_test.drop(columns=['date', 'is_ext'], inplace=True)

# Convert pandas columns into arrays
train_data = df_train.values
val_data = df_val.values
test_data = df_test.values
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

df_train.head()
# Out:
# Training data shape: (8761, 5)
# Validation data shape: (1095, 5)
# Test data shape: (1095, 5)
# C:\Users\mrsca\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        open      high       low     close    volume
# 0 -1.507780 -1.515642 -1.522882 -1.519477 -0.342147
# 1 -1.531133 -1.538941 -1.546295 -1.554513  0.777023
# 2 -1.554485 -1.562241 -1.569708 -1.566192  0.828991
# 3 -1.566162 -1.550591 -1.569708 -1.566192  0.350747
# 4 -1.566162 -1.562241 -1.569708 -1.577870  0.262698

# %%
fig = plt.figure(figsize=(15,10))
st = fig.suptitle("Data Separation", fontsize=20)
st.set_y(0.92)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(np.arange(train_data.shape[0]), df_train['close'], label='Training data')

ax1.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['close'], label='Validation data')

ax1.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['close'], label='Test data')
ax1.set_xlabel('Date')
ax1.set_ylabel('Normalized Closing Returns')

###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(np.arange(train_data.shape[0]), df_train['volume'], label='Training data')

ax2.plot(np.arange(train_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]), df_val['volume'], label='Validation data')

ax2.plot(np.arange(train_data.shape[0]+val_data.shape[0], 
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['volume'], label='Test data')
ax2.set_xlabel('date')
ax2.set_ylabel('Normalized Volume Changes')

plt.legend(loc='best')

# %%
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(train_data[:, 3][i]) #Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 3][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 3][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (8633, 128, 5) (8633,)
# (967, 128, 5) (967,)

# %%
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
print('Tensorflow version: {}'.format(tf.__version__))
import warnings
warnings.filterwarnings('ignore')
# Out:
# Tensorflow version: 2.8.0

# %%
def create_model():
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.LSTM(64, input_shape=(seq_len, 5), return_sequences=True))
  model.add(tf.keras.layers.LSTM(64, return_sequences=True))
  model.add(tf.keras.layers.LSTM(32))
  model.add(tf.keras.layers.Dense(1))#, activation=tf.nn.relu))
  model.compile(optimizer="adam", loss="mean_squared_error")
  return model

# %%
model = create_model()

model.summary()

model.fit(X_train, y_train,
              batch_size=1024,
              epochs=50,
              validation_data=(X_val, y_val),)    

###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128, 64)           17920
#
#  lstm_1 (LSTM)               (None, 128, 64)           33024
#
#  lstm_2 (LSTM)               (None, 32)                12416
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 63,393
# Trainable params: 63,393
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 9/9 [==============================] - 33s 3s/step - loss: 0.1474 - val_loss: 0.1026
# Epoch 2/50
# 9/9 [==============================] - 26s 3s/step - loss: 0.0332 - val_loss: 0.2545
# Epoch 3/50
# 9/9 [==============================] - 30s 3s/step - loss: 0.0145 - val_loss: 0.2272
# Epoch 4/50
# 9/9 [==============================] - 32s 4s/step - loss: 0.0084 - val_loss: 0.1224
# Epoch 5/50
# 9/9 [==============================] - 34s 4s/step - loss: 0.0053 - val_loss: 0.0969
# Epoch 6/50
# 9/9 [==============================] - 36s 4s/step - loss: 0.0039 - val_loss: 0.0552
# Epoch 7/50
# 9/9 [==============================] - 36s 4s/step - loss: 0.0031 - val_loss: 0.0421
# Epoch 8/50
# 9/9 [==============================] - 37s 4s/step - loss: 0.0028 - val_loss: 0.0369
# Epoch 9/50
# 9/9 [==============================] - 38s 4s/step - loss: 0.0026 - val_loss: 0.0351
# Epoch 10/50
# 9/9 [==============================] - 40s 4s/step - loss: 0.0025 - val_loss: 0.0355
# Epoch 11/50
# 9/9 [==============================] - 42s 5s/step - loss: 0.0024 - val_loss: 0.0332
# Epoch 12/50
# 9/9 [==============================] - 43s 5s/step - loss: 0.0024 - val_loss: 0.0296
# Epoch 13/50
# 9/9 [==============================] - 44s 5s/step - loss: 0.0024 - val_loss: 0.0294
# Epoch 14/50
# 9/9 [==============================] - 45s 5s/step - loss: 0.0023 - val_loss: 0.0260
# Epoch 15/50
# 9/9 [==============================] - 45s 5s/step - loss: 0.0023 - val_loss: 0.0252
# Epoch 16/50
# 9/9 [==============================] - 45s 5s/step - loss: 0.0023 - val_loss: 0.0246
# Epoch 17/50
# 9/9 [==============================] - 46s 5s/step - loss: 0.0022 - val_loss: 0.0223
# Epoch 18/50
# 9/9 [==============================] - 46s 5s/step - loss: 0.0022 - val_loss: 0.0229
# Epoch 19/50
# 9/9 [==============================] - 46s 5s/step - loss: 0.0022 - val_loss: 0.0221
# Epoch 20/50
# 9/9 [==============================] - 47s 5s/step - loss: 0.0022 - val_loss: 0.0174
# Epoch 21/50
# 9/9 [==============================] - 48s 5s/step - loss: 0.0021 - val_loss: 0.0178
# Epoch 22/50
# 9/9 [==============================] - 87s 10s/step - loss: 0.0021 - val_loss: 0.0165
# Epoch 23/50
# 9/9 [==============================] - 44s 5s/step - loss: 0.0021 - val_loss: 0.0171
# Epoch 24/50
# 9/9 [==============================] - 45s 5s/step - loss: 0.0021 - val_loss: 0.0151
# Epoch 25/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.0021 - val_loss: 0.0141
# Epoch 26/50
# 9/9 [==============================] - 51s 6s/step - loss: 0.0021 - val_loss: 0.0146
# Epoch 27/50
# 9/9 [==============================] - 52s 6s/step - loss: 0.0020 - val_loss: 0.0135
# Epoch 28/50
# 9/9 [==============================] - 52s 6s/step - loss: 0.0020 - val_loss: 0.0121
# Epoch 29/50
# 9/9 [==============================] - 53s 6s/step - loss: 0.0020 - val_loss: 0.0118
# Epoch 30/50
# 9/9 [==============================] - 57s 6s/step - loss: 0.0020 - val_loss: 0.0109
# Epoch 31/50
# 9/9 [==============================] - 56s 6s/step - loss: 0.0020 - val_loss: 0.0101
# Epoch 32/50
# 9/9 [==============================] - 56s 6s/step - loss: 0.0020 - val_loss: 0.0099
# Epoch 33/50
# 9/9 [==============================] - 56s 6s/step - loss: 0.0019 - val_loss: 0.0092
# Epoch 34/50
# 9/9 [==============================] - 55s 6s/step - loss: 0.0019 - val_loss: 0.0075
# Epoch 35/50
# 9/9 [==============================] - 55s 6s/step - loss: 0.0019 - val_loss: 0.0058
# Epoch 36/50
# 9/9 [==============================] - 56s 6s/step - loss: 0.0019 - val_loss: 0.0078
# Epoch 37/50
# 9/9 [==============================] - 58s 6s/step - loss: 0.0019 - val_loss: 0.0085
# Epoch 38/50
# 9/9 [==============================] - 57s 6s/step - loss: 0.0019 - val_loss: 0.0069
# Epoch 39/50
# 9/9 [==============================] - 57s 6s/step - loss: 0.0019 - val_loss: 0.0084
# Epoch 40/50
# 9/9 [==============================] - 58s 6s/step - loss: 0.0018 - val_loss: 0.0069
# Epoch 41/50
# 9/9 [==============================] - 58s 6s/step - loss: 0.0018 - val_loss: 0.0067
# Epoch 42/50
# 9/9 [==============================] - 57s 6s/step - loss: 0.0018 - val_loss: 0.0054
# Epoch 43/50
# 9/9 [==============================] - 58s 6s/step - loss: 0.0018 - val_loss: 0.0063
# Epoch 44/50
# 9/9 [==============================] - 59s 7s/step - loss: 0.0018 - val_loss: 0.0047
# Epoch 45/50
# 9/9 [==============================] - 57s 6s/step - loss: 0.0018 - val_loss: 0.0040
# Epoch 46/50
# 9/9 [==============================] - 57s 6s/step - loss: 0.0018 - val_loss: 0.0050
# Epoch 47/50
# 9/9 [==============================] - 58s 7s/step - loss: 0.0017 - val_loss: 0.0053
# Epoch 48/50
# 9/9 [==============================] - 58s 6s/step - loss: 0.0017 - val_loss: 0.0063
# Epoch 49/50
# 9/9 [==============================] - 55s 6s/step - loss: 0.0017 - val_loss: 0.0056
# Epoch 50/50
# 9/9 [==============================] - 56s 6s/step - loss: 0.0017 - val_loss: 0.0062

# %%
'''Display results'''

fig = plt.figure(figsize=(15,15))
st = fig.suptitle("Moving Average - LSTM Model", fontsize=22)
st.set_y(1.02)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='IBM Closing Returns')
ax11.plot(np.arange(seq_len-8, train_pred.shape[0]+seq_len-8),train_pred, label='Predicted IBM Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('IBM Closing Returns')

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='IBM Closing Returns')
ax21.plot(np.arange(seq_len-8, val_pred.shape[0]+seq_len-8),val_pred, label='Predicted IBM Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='IBM Closing Returns')
ax31.plot(np.arange(seq_len-8, test_pred.shape[0]+seq_len-8), test_pred, label='Predicted IBM Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('IBM Closing Returns')
 
plt.tight_layout()
plt.legend(loc='best')
